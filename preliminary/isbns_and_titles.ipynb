# %%
import pandas as pd
import ast
from tqdm import tqdm

df = pd.read_csv("isbns.csv")

titles = []
isbns = []
for i, row in tqdm(df.iterrows(), total=len(df)):
    titles.append(row["filename"])
    isbn_1d = ast.literal_eval(row["isbns"])
    isbn = ""
    if len(isbn_1d) == 1 or len(str(isbn_1d[0])) == 13:
        isbns.append(isbn_1d[0])
    else:
        isbn_1d = [str(isbn) for isbn in isbn_1d]
        isbn_1d.sort(key=len, reverse=True)
        isbns.append(int(isbn_1d[0]))
        
isbn_to_title = {isbn: title for isbn, title in zip(isbns, titles)}

df_isbns_and_titles = pd.DataFrame({"isbn": isbns, "filename": titles})
df_isbns_and_titles.to_csv("isbns_and_titles.csv", index=False)
# Out:
# /tmp/ipykernel_2125634/2450050541.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# 100%|██████████| 174918/174918 [00:12<00:00, 14395.17it/s]

# %%
df_isbns_and_titles = pd.read_csv("isbns_and_titles.csv")
df_isbns_and_titles
# Out:
#                  isbn                                           filename
# 0       9780807507377  The Day of the Dead Mystery - Gertrude Chandle...
# 1       9780062691569           Into the Planet - Jill Heinerth.epub.txt
# 2       9781607741343      Bon Appetit, Y'all - Virginia Willis.epub.txt
# 3       9780241311332  RHS Great British Village Show - Thane Prince....
# 4       9780231531641         Rewiring the Real - Mark C Taylor.epub.txt
# ...               ...                                                ...
# 174913      919626106                       Lependu - Don McKay.epub.txt
# 174914  9781504027465       The Bastard King - Harry Turtledove.epub.txt
# 174915  9780440000594  Benedict Jacka - Alex Verus 10 - Fallen [retai...
# 174916  9781609451523  Bound in Venice - Alessandro Marzo Magno.epub.txt
# 174917  9781612000701                   Gunship Ace - Al Venter.epub.txt
#
# [174918 rows x 2 columns]
